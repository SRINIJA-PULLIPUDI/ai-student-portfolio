# %% [markdown]
# <a href="https://colab.research.google.com/github/SRINIJA-PULLIPUDI/ai-student-portfolio/blob/main/Day1_Setup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q google-genai

# %%
import os, getpass
os.environ['GEMINI_API_KEY'] = getpass.getpass('Paste your Google AI Studio key: ')
# Out:
# Paste your Google AI Studio key: ··········

# %%
from google import genai
client = genai.Client(api_key=os.environ['GEMINI_API_KEY'])

resp = client.models.generate_content(
    model='gemini-2.5-flash',
    contents='Explain the 5-Layer AI Skill Pyramid in 4 short bullet points.'
)
print(resp.text)
# Out:
# The 5-Layer AI Skill Pyramid outlines the diverse expertise needed for successful AI implementation, from foundational tech to strategic leadership:
#
# *   **Foundation & Core Tech:** Encompasses data collection, infrastructure management, and the development/training of AI models (e.g., ML algorithms, neural networks).
# *   **Application & Integration:** Focuses on building and deploying AI into usable products, services, and systems for end-users or business processes.
# *   **Domain & Strategy:** Involves understanding specific industry problems, business contexts, and how AI can create tangible value and solve real-world challenges.
# *   **Leadership & Ethics:** Guides the overall AI vision, strategic direction, resource allocation, and ensures responsible, ethical, and sustainable AI development and deployment.
